# %% [markdown]
# # Lab 4: Introduction to Python Environments
# ## Anaconda & Jupyter Notebook
#
# This lab introduces **Anaconda** and **JupyterLab/Notebook, which we will use throughout the course.

# %% [markdown]
# ## Learning Objectives
# - Launch Jupyter Notebook using Anaconda
# - Create and run Python code cells
# - Use basic Python syntax
# - Work with common Python data types

# %% [markdown]
# ## 🔹 Part I — Getting Started with Jupyter Notebook
# Jupyter notebooks are made of **cells**.
# - Code cells execute Python
# - Markdown cells contain text

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
print('Hello, world!')

# %% [markdown]
# ## 🔹 Part II — Basic Python Syntax

# %%
# Printing output
print("Welcome to Python!")

# Variables
x = 10
y = 5

# Arithmetic
print(x + y)
print(x * y)
# Out:
# Welcome to Python!
# 15
# 50

# %%
print("Thank you")
a = 15
z = 20
print(a + z)
print(a * z)

# %% [markdown]
# ## 🔹 Part III — Python Data Types

# %%
# Numbers
a = 3
b = 2.5
print(a, b)

# Strings
name = "Student"
print("Hello,", name)

# Lists
nums = [1, 2, 3, 4]
print(nums)
# Out:
# 3 2.5
# Hello, Student
# [1, 2, 3, 4]

# %%
c = 6
d = 7
print(c, d)
name = "Teacher"
print("Hello,", name)
prme = [2, 3, 7, 11]
print(prme)

# %% [markdown]
# ## 🔹 Part IV — Input and Output

# %%
user = input("Enter your name: ")
print("Nice to meet you,", user)
# Out:
# Enter your name:  Abit Jurkuch
# Nice to meet you, Abit Jurkuch

# %%
tk = input("Enter your Ticket number: ")
print("All abord ticket number,", tk)
# Out:
# Enter your Ticket #:  3
# All abord ticket #, 3

# %% [markdown]
# ## Student Tasks
# Complete the tasks below.

# %% [markdown]
# ### Task 1 — Modify Output
# - Change the print statement to display your name.

# %%
print('My name is Carl')
# Out:
# My name is Carl

# %% [markdown]
# ### Task 2 — Variables
# - Create two numbers and print their sum and product.

# %%
# Your code here
X=4
y=3
print(x*y)
print(x+y)

# %% [markdown]
# ### Task 3 — Lists
# - Create a list of 5 numbers and print its length.

# %%
# Your code here
odd=[1,3,5,7,9]
print (odd)
print(len(odd))
# Out:
# [1, 3, 5, 7, 9]
# 5

# %% [markdown]
# ### Task 4 — Reflection
# - Add a Markdown cell explaining what Jupyter Notebook is.

# %% [markdown]
# Jupyter Notebook is a website used for creating documents that contain code in boxes called cells it is versatile as it includes multiple coding languages.
